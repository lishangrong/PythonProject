# %%
"""
需求：预计于Pandas 统计班级学员的各科成绩的最高分、最低分、平均分
准备: pip install pandas==2.3.3
"""
import pandas as pd
# 构造DataFrame --- 创建数据集（学员成绩）
df = pd.DataFrame([
    {"姓名":"向往", "语文":90, "数学":80, "英语":70},
    {"姓名":"小王", "语文":80, "数学":90, "英语":80},
    {"姓名":"小李", "语文":70, "数学":80, "英语":90},
    {"姓名":"小张", "语文":60, "数学":70, "英语":80},
    {"姓名":"小赵", "语文":80, "数学":70, "英语":90},
    {"姓名":"小孙", "语文":90, "数学":80, "英语":76},
    {"姓名":"小吴", "语文":81, "数学":90, "英语":80},
    {"姓名":"小郑", "语文":70, "数学":80, "英语":90},
    {"姓名":"小王2", "语文":60, "数学":77, "英语":80},
    {"姓名":"小王3", "语文":80, "数学":70, "英语":90},
    {"姓名":"小王4", "语文":91, "数学":88, "英语":93},
])

# 统计计算
print(f" 语文最高分：{df["语文"].max()}, 最低分:{df["语文"].min()}, 平均分：{df["语文"].mean():.2f}")
print(f" 数学最高分：{df["数学"].max()}, 最低分:{df["数学"].min()}, 平均分：{df["数学"].mean():.2f}")
print(f" 英语最高分：{df["英语"].max()}, 最低分:{df["英语"].min()}, 平均分：{df["英语"].mean():.2f}")
# Out:
#  语文最高分：91, 最低分:60, 平均分：77.45
#  数学最高分：90, 最低分:70, 平均分：79.55
#  英语最高分：93, 最低分:70, 平均分：83.55
