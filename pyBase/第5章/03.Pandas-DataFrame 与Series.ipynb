# %%
import pandas as pd
df = pd.DataFrame([
    {"姓名":"向往", "语文":90, "数学":80, "英语":70},
    {"姓名":"小王", "语文":80, "数学":90, "英语":80},
    {"姓名":"小李", "语文":70, "数学":80, "英语":90},
])
df

df1 = pd.DataFrame({
    "姓名":["小王", "小王2", "小王3", "小王4"],
    "语文":[80, 60, 80, 91],
    "数学":[90, 77, 70, 88],
    "英语":[80, 80, 90, 93]
})
df1

df2 = pd.DataFrame([
    ("张三", 85, 92, 78),
    ("小王", 90, 80, 90),
    ("小李", 70, 80, 90),
    ], columns=["姓名", "语文", "数学", "英语"])

df2

df3 = pd.DataFrame([
    ["张三", 85, 92, 78],
    ["小王", 90, 80, 90],
    ["小李", 70, 80, 90]
    ], columns=["姓名", "语文", "数学", "英语"], index=['a', 'b', 'c'])

df3
# DataFrame 常见属性 -- index, columns, values, size, dtype, shape
# df3.index.to_list() # index 索引
# df3.columns.to_list() # columns 列名
# df3.values.tolist()  #values 值
# df3.size # size 元素个数
# df3.dtypes  # 数据类型
df3.shape  # shape 数据维度(行, 列)
# Out:
# (3, 4)

# %%
#Series
s1 = pd.Series([1, 2, 3, 4, 5])
s2 = pd.Series((1, 2, 3, 4, 5), index=['a', 'b', 'c', 'd', 'e'])
s3 = pd.Series({"a":1, "b":2, "c":3, "d":4, "e":5})
s4 = df3["语文"]
s4

# Series 常见属性 -- index, values, size, dtype, shape
s1.index.to_list()
s1.values.tolist()
s1.size
s1.dtype
s1.shape
# Out:
# a    85
# b    90
# c    70
# Name: 语文, dtype: int64
